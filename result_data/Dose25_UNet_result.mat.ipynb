# %%
from matplotlib import pyplot as plt
import scipy.io as sio
import numpy as np

# %%
SMALL_SIZE = 13
MEDIUM_SIZE = 16
BIGGER_SIZE = 24

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

line_markers = ['-.','-,','-o','-v','-^','-<','->','-1','-2','-3','-4','-s','-p','-*','-h','-H','-+','-x','-D','-d','-|','-_']

# %%
iter_num = 3

# %%
tr_loss_arr = []
te_loss_arr = []
psnr_arr = []
ssim_arr = []
denoiser_img_arr = []

for i in range(iter_num+1):
    file_name = 'Dose25_UNet_iter_'+str(i)+'_result'
    f = sio.loadmat(file_name)
    
    tr_loss_arr.append(f['tr_loss_arr'])
    te_loss_arr.append(f['te_loss_arr'])
    psnr_arr.append(f['psnr_arr'])
    ssim_arr.append(f['ssim_arr'])
    denoiser_img_arr.append(f['denoised_img_arr'])

# %%
plt.figure(figsize=[10,8])

plt.plot(psnr_arr[0],line_markers[1], linewidth=2.5, label='Iter = 0')
plt.plot(psnr_arr[1],line_markers[1], linewidth=2.5, label='Iter = 1')
plt.plot(psnr_arr[2],line_markers[1], linewidth=2.5, label='Iter = 2')
plt.plot(psnr_arr[3],line_markers[1], linewidth=2.5, label='Iter = 3')
        
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=[10,8])

plt.plot(ssim_arr[0],line_markers[1], linewidth=2.5, label='Iter = 0')
plt.plot(ssim_arr[1],line_markers[1], linewidth=2.5, label='Iter = 1')
plt.plot(ssim_arr[2],line_markers[1], linewidth=2.5, label='Iter = 2')
plt.plot(ssim_arr[3],line_markers[1], linewidth=2.5, label='Iter = 3')
        
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.legend(loc='best')
plt.show()
